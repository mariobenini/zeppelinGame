# %%
# importar as bibliotecas que serão utilizadas neste script
import random
from time import sleep

# mensagem inicial e primeiro input para selecionar quantos jogadores
# transformará a resposta em minúscula e selecionará a primeira letra apenas para tentar evitar alguns erros de digitação
jogo = input('BEM VINDO(A) AO ZEPPELIN!\nSERÃO QUANTOS JOGADORES?\nUM ou DOIS jogadores: ').lower().strip()[0]

# modo single player: se for dado input de qualquer palavra com a letra inicial 'u'
if jogo == 'u':
    
    # lista com os nomes dos chefões do jogo
    bossList = ['PLANT','PAGE','BONHAM','JONES']
    
    # sorteia qual chefão de 'bossList' será utilizado na partida
    boss = random.choice(bossList)
    
    # sorteia um numero entre 1 e 100, ambos inclusos
    numberSolo = random.randint(1,100)
    
    # inicia as variáveis
    palpiteSolo = 0
    chancesSolo = 0
    
    # input do nome do jogador
    print('\n',boss,': Quem ousa me desafiar?')
    pSolo = input('\nSeu nome: ')
    print('\n',boss,':',pSolo,', qual dificuldade você quer?')
    
    # input da dificuldade  
    dificuldadeSolo = input('FACIL, NORMAL ou IMPOSSIVEL: ').lower().strip()[0]
    
    # dificuldade facil: se for dado input de qualquer palavra com a letra inicial 'f'
    if dificuldadeSolo == 'f':
        
        # textos com introdução da partida e input de sim ou nao para começar a partida. Utilização da variável 'pSolo' dentro do texto
        print('\n')
        print(boss,': Muito bem, não esperava muito de você mesmo...')
        sleep(2)
        print(boss,': O jogo é simples, você terá 10 chances para adivinhar em qual número estou pensando entre 1 e 100.')
        print(boss,': É claro que darei algumas dicas no caminho para você pensar que está à minha altura.')
        sleep(2)
        print(boss,': Prepare-se,',pSolo,', seu pesadelo está prestes a começar.....\n')
        print(boss,': Está pronto?')
        startSolo = input('SIM ou NAO: ').lower().strip()[0]
        
        # começa o jogo: se for dado input de qualquer palavra com a letra inicial 's'
        if startSolo == 's':
            
            # começa a contagem de chances do jogador 'chancesSolo'. Quando ultrapassar as 10 rodadas, o while loop encerra
            while chancesSolo < 10:
                
                # a cada input dado pelo jogador, irá somar um ('+= 1') à 'chancesSolo' e verificar se o input é o correto
                chancesSolo += 1
                palpiteSolo = int(input('O número é.. '))
                
                # se o input for correto, o jogo acaba
                if numberSolo == palpiteSolo:
                    print(boss,': Finalmente,',pSolo,', adivinhou após',chancesSolo,'tentativas. Talvez você queira enfrentar a próxima dificuldade, e não essa brincadeira de criança!')
                    break
                
                # se o input for menor ou maior que o correto, uma dica será dada
                elif numberSolo > palpiteSolo and chancesSolo <10:
                    print(boss,': Tente um número maior! Essa foi sua tentativa de nº',chancesSolo,'\n')
                elif numberSolo < palpiteSolo and chancesSolo <10:
                    print(boss,': Tente um número menor! Essa foi sua tentativa de nº',chancesSolo,'\n')
            
            # se as chances ultrapassarem as 10 tentativas, o jogo é encerrado e o jogador perde
            if chancesSolo >= 10:
                print('\n',boss,'HA HA HA HA eu sabia que não conseguiria.. o número correto é',numberSolo)
                print(boss,': Boa sorte na próxima vez!')
        
        # termina o jogo se qualquer outro valor for dado além do 's' de pronto para jogar
        else:
            print(boss,': Volte quando tiver mais coragem..')
    
    # dificuldade normal: se for dado input de qualquer palavra com a letra inicial 'n'
    elif dificuldadeSolo == 'n':
        
        # textos com introdução da partida e input de sim ou nao para começar a partida. Utilização da variável 'pSolo' dentro do texto
        print('\n')
        print(boss,': Muito bem, a escolha é sua, mas assim nunca me enfrentará de verdade...')
        sleep(2)
        print(boss,': O jogo é simples, você terá 5 chances para adivinhar em qual número estou pensando entre 1 e 100.')
        print(boss,': É claro que darei algumas dicas no caminho para você pensar que está à minha altura.')
        sleep(2)
        print(boss,': Prepare-se,',pSolo,', seu pesadelo está prestes a começar.....')
        print('\n')
        print(boss,': Está pronto?')
        startSolo = input('SIM ou NAO: ').lower().strip()[0]
        
        # começa o jogo: se for dado input de qualquer palavra com a letra inicial 's'
        if startSolo == 's':
            
            # começa a contagem de chances do jogador 'chancesSolo'. Quando ultrapassar as 5 rodadas, o while loop encerra
            while chancesSolo < 5:
                
                # a cada input dado pelo jogador, irá somar um ('+= 1') à 'chancesSolo' e verificar se o input é o correto
                chancesSolo += 1
                palpiteSolo = int(input('O número é.. '))
                
                # se o input for correto, o jogo acaba
                if numberSolo == palpiteSolo:
                    print(boss,': Finalmente,',pSolo,', adivinhou após',chancesSolo,'tentativas. Talvez você queira me enfrentar de verdade na próxima dificuldade!')
                    break
                
                # se o input for menor ou maior que o correto, uma dica será dada
                elif numberSolo > palpiteSolo and chancesSolo <5:
                    print(boss,': Tente um número maior! Essa foi sua tentativa de nº',chancesSolo,'\n')
                elif numberSolo < palpiteSolo and chancesSolo <5:
                    print(boss,': Tente um número menor! Essa foi sua tentativa de nº',chancesSolo,'\n')
            
            # se as chances ultrapassarem as 5 tentativas, o jogo é encerrado e o jogador perde
            if chancesSolo >= 5:
                print('\n')
                print(boss,': HA HA HA HA eu sabia que não conseguiria.. o número correto é',numberSolo)
                print(boss,': Boa sorte na próxima vez!')
        
        # termina o jogo se qualquer outro valor for dado além do 's' de pronto para jogar
        else:
            print('Volte quando tiver mais coragem..')
    
    # dificuldade impossivel: se for dado input de qualquer palavra com a letra inicial 'i'
    elif dificuldadeSolo == 'i':
        
        # textos com introdução da partida e input de sim ou nao para começar a partida. Utilização da variável 'pSolo' dentro do texto
        print('\n')
        print(boss,': HA HA HA')
        print(boss,': Finalmente alguém com coragem para me enfrentar de verdade!\nOu seria apenas um louco?')
        sleep(3)
        print(boss,': O jogo é simples, você terá 10 chances para adivinhar em qual número estou pensando entre 1 e 100.')
        print(boss,': Agora o jogo é sério, nenhuma dica será fornecida.')
        sleep(4)
        print(boss,': Porém, o nosso verdadeiro duelo só começa após esse joguinho infantil, estamos apenas no aquecimento!')
        sleep(3)
        print('\n')
        print(boss,': Prepare-se,',pSolo,', seu pesadelo está prestes a começar.....')
        print(boss,': Está pronto?')
        startSolo = input('SIM ou NAO: ').lower().strip()[0]
        
        # começa o jogo: se for dado input de qualquer palavra com a letra inicial 's'
        if startSolo == 's':
            
            # começa a contagem de chances do jogador 'chancesSolo'. Quando ultrapassar as 10 rodadas, o while loop encerra
            while chancesSolo < 10:
                
                # a cada input dado pelo jogador, irá somar um ('+= 1') à 'chancesSolo' e verificar se o input é o correto
                chancesSolo += 1
                palpiteSolo = int(input('O número é.. '))
                
                # se o input for correto, começa a fase bonus
                if numberSolo == palpiteSolo:
                    print(boss,': Finalmente,',pSolo,', adivinhou após',chancesSolo,'tentativas. Agora sim podemos começar nosso verdadeiro duelo!')
                    
                    # novo número é gerado entre 1 e 10, ambos inclusos
                    numberFinal = random.randint(1,10)
                    print('\n...')
                    sleep(3)
                    print('\n.........')
                    sleep(4)
                    print('\n....!!KABOOOOM!!....\n')
                    sleep(4)
                    print(pSolo,': o que foi essa explosão?! O chão está se abrindo!!\n\n...\n')
                    sleep(3)
                    print(boss,': HA HA HA HA')
                    print(boss,': Nem me lembro mais da última vez em que tive um adversário à altura!')
                    print(boss,': Provavelmente em uma Era sem esses falsos Deuses..')
                    sleep(4)
                    print(boss,': Enfim, vamos logo com isso. Você tem apenas uma chance para adivinhar o próximo número entre 1 e 10.')
                    print(boss,': Sem dicas, sem chances, é agora ou nunca! Você está pronto?')
                    startBoss = input('SIM ou NAO: ').lower().strip()[0]
                    
                    # começa a fase bonus: se for dado input de qualquer palavra com a letra inicial 's'
                    if startBoss == 's':
                        palpiteBoss = int(input('O número é.. '))
                        
                        # se o input for correto, o jogo acaba e o jogador vence a partida
                        if numberFinal == palpiteBoss:
                            sleep(3)
                            print('......')
                            sleep(3)
                            print(boss,': NÃO É POSSÍVEL QUE FUI DERROTADO! Isso não ficará assim,',pSolo,'.. foi apenas um golpe de sorte.\nTenho certeza que a história será diferente contra meus irmãos! HA HA HA HA')
                            sleep(2)
                            print('\n~Parabéns,',pSolo,'! Você derrotou',boss,', boa sorte contra os outros!~')
                        
                        # se o input for incorreto, o jogo é encerrado e o jogador perde
                        else:
                            print('\n')
                            print(boss,': HA HA HA HA eu sabia que não conseguiria.. o número correto é',numberFinal)
                            print(boss,': Boa sorte na próxima vez!')
                    break
                
                # se o input for incorreto, nenhuma dica será dada, apenas o numero da tentativa
                else:
                    print(boss,': Errado! Essa foi sua tentativa de nº',chancesSolo,'\n')
                    
            # se as chances ultrapassarem as 10 tentativas, o jogo é encerrado e o jogador perde
            if chancesSolo >= 10:
                print('\n')
                print(boss,': HA HA HA HA eu sabia que não conseguiria.. o número correto é',numberSolo)
                print(boss,': Boa sorte na próxima vez!')
        
        # termina o jogo se qualquer outro valor for dado além do 's' de pronto para jogar
        else:
            print(boss,': Volte quando tiver mais coragem..')

# modo multiplayer: se for dado input de qualquer palavra sem ter a letra inicial 'u'
else:
    
    # input dos nomes dos jogadores
    player1 = input('Player 1, qual seu nome?\nMeu nome é: ')
    player2 = input('\nPlayer 2, qual seu nome?\nMeu nome é: ')
    print('\nMuito bem, o jogo é simples: vocês deverão adivinhar qual número estou pensando entre 1 e 20')
    print('Não há dicas, apenas um duelo sincero. Estão prontos(as)?')
    
    # input de sim ou nao para verificar se os jogadores estão prontos
    startDuo = input('SIM ou NAO: ').lower().strip()[0]
    
    # começa o jogo: se for dado input de qualquer palavra com a letra inicial 's'
    if startDuo == 's':
        
        # numero é gerado aleatoriamente entre 1 e 20, ambos inclusos
        numberDuo = random.randint(1,20)
        
        # inicia as variáveis
        p1Tentativa = 0
        p2Tentativa = 0
        p1Turn = True
        p2Turn = False
        tentativas = 0
        
        # enquanto o palpite do player1 E player2 for diferente do numero sorteado, irá somar um ('+= 1') à 'tentativas'
        while p1Tentativa != numberDuo and p2Tentativa != numberDuo:
            tentativas += 1
                        
            # enquanto 'p1Turn' for true, vez do player1 dar o input. Após input, 'p1Turn' recebe false
            while p1Turn:
                print('\n',player1,', sua vez.')
                p1Tentativa = int(input('O número é.. '))
                p1Turn = False
                p2Turn = True
                
            # enquanto 'p2Turn' for true, vez do player2 dar o input. Após input, 'p2Turn' recebe false
            while p2Turn:
                print('\n',player2,', sua vez.')
                p2Tentativa = int(input('O número é.. '))
                p1Turn = True
                p2Turn = False
               
            # mensagem de que ambos erraram            
            if p1Tentativa != numberDuo and p2Tentativa != numberDuo:
                print('\nNinguém acertou!\n')
        
        # se player1 acertar o numero e o player2 não acertar, o jogo acaba e player1 é o vencedor
        if p1Tentativa == numberDuo and p2Tentativa != numberDuo:
            print('\nParabéns,',player1,', por adivinhar o número',numberDuo,', você venceu com',tentativas,'tentativas!')

        # se player2 acertar o numero e o player1 não acertar, o jogo acaba e player2 é o vencedor    
        elif p2Tentativa == numberDuo and p1Tentativa != numberDuo:
            print('\nParabéns,',player2,', por adivinhar o número',numberDuo,', você venceu com',tentativas,'tentativas!')

        # se player1 e o player2 acertarem o numero , o jogo acaba e ambos são declarados vencedores
        elif p1Tentativa == numberDuo and p2Tentativa == numberDuo:
            print('\nParabéns,',player1,'e',player2,', por adivinharem o número',numberDuo,', vocês venceram com',tentativas,'tentativas!')
# Out:
# BEM VINDO(A) AO ZEPPELIN!
# SERÃO QUANTOS JOGADORES?
# UM ou DOIS jogadores: um
#
#  JONES : Quem ousa me desafiar?
#
# Seu nome: Mario
#
#  JONES : Mario , qual dificuldade você quer?
# FACIL, NORMAL ou IMPOSSIVEL: facil
#
#
# JONES : Muito bem, não esperava muito de você mesmo...
# JONES : O jogo é simples, você terá 10 chances para adivinhar em qual número estou pensando entre 0 e 100.
# JONES : É claro que darei algumas dicas no caminho para você pensar que está à minha altura.
# JONES : Prepare-se, Mario , seu pesadelo está prestes a começar.....
#
# JONES : Está pronto?
# SIM ou NAO: s
# O número é.. 78
# JONES : Tente um número menor! Essa foi sua tentativa de nº 1
#
# O número é.. 50
# JONES : Tente um número maior! Essa foi sua tentativa de nº 2
#
# O número é.. 60
# JONES : Tente um número menor! Essa foi sua tentativa de nº 3
#
# O número é.. 55
# ...
